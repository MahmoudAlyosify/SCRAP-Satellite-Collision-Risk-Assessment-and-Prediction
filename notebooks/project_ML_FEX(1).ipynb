# %%
from datasets import load_dataset

ds = load_dataset("mahmoudalyosify/SCRAP")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_columns', None, 'display.max_rows', None)

# %%
! pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\electronica care\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\electronica care\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\electronica care\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from xgboost) (1.15.3)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_train=pd.DataFrame(ds['train'])
df_test=pd.DataFrame(ds['test'])

# %%
df_train.head()
# Out:
#    event_id  time_to_tca  mission_id       risk  max_risk_estimate  max_risk_scaling  miss_distance  relative_speed  relative_position_r  relative_position_t  relative_position_n  relative_velocity_r  relative_velocity_t  relative_velocity_n  t_time_lastob_start  t_time_lastob_end  t_recommended_od_span  t_actual_od_span  t_obs_available  t_obs_used  t_residuals_accepted  t_weighted_rms  t_rcs_estimate  t_cd_area_over_mass  t_cr_area_over_mass    t_sedr    t_j2k_sma  t_j2k_ecc  t_j2k_inc    t_ct_r    t_cn_r    t_cn_t  t_crdot_r  t_crdot_t  t_crdot_n  t_ctdot_r  t_ctdot_t  t_ctdot_n  t_ctdot_rdot  t_cndot_r  t_cndot_t  t_cndot_n  t_cndot_rdot  t_cndot_tdot c_object_type  c_time_lastob_start  c_time_lastob_end  c_recommended_od_span  c_actual_od_span  c_obs_available  ...  c_rcs_estimate  c_cd_area_over_mass  c_cr_area_over_mass    c_sedr    c_j2k_sma  c_j2k_ecc  c_j2k_inc    c_ct_r    c_cn_r    c_cn_t  c_crdot_r  c_crdot_t  c_crdot_n  c_ctdot_r  c_ctdot_t  c_ctdot_n  c_ctdot_rdot  \
# 0         0     1.566798           5 -10.204955          -7.834756          8.602101        14923.0         13792.0                453.8               5976.6             -13666.8                 -7.2             -12637.0              -5525.9                  1.0                0.0                   3.78              3.78              459         458                  98.9           1.265           0.402             0.013826             0.007173  0.000051  6996.918867   0.003997  97.806412 -0.397969  0.292258  0.040799   0.394221  -0.999674  -0.038498  -0.981098   0.214612  -0.316493     -0.210247   0.170737  -0.001551   0.531593      0.002117     -0.179278       UNKNOWN                180.0                2.0                  15.85             15.85             15.0  ...             NaN             0.348701             0.126607  0.001406  7006.607320   0.003144  74.045735 -0.824859  0.473976 -0.002576   0.825216  -0.999998   0.003565  -0.732954   0.220006  -0.814249     -0.220621
# 1         0     1.207494           5 -10.355758          -7.848937          8.956374        14544.0         13792.0                474.3               5821.2             -13319.8                 -7.0             -12637.0              -5525.9                  1.0                0.0                   3.79              3.79              456         455                  98.5           1.270           0.402             0.013487             0.009139  0.000060  6996.920255   0.003996  97.806420 -0.073137  0.297366  0.060541   0.069652  -0.998192  -0.052511  -0.994240  -0.029644  -0.302333      0.034030   0.179696   0.001552   0.561142     -0.005165     -0.181036       UNKNOWN                180.0                2.0                  15.85             15.85             15.0  ...             NaN             0.348701             0.126607  0.001406  7006.621053   0.003144  74.045736 -0.818207  0.482754 -0.003578   0.818573  -0.999998   0.004574  -0.728759   0.202595  -0.817490     -0.203216
# 3   0.259681   0.195808   0.721874     -0.196097     -0.675656     1.0     2.0  646.747747  590.818806  650.515635  606.456229           -73.571021 -23.618769   0.029079            435.376626               12454.776555               4.382408e+16   3.075781  261.759718   22.232870  54107.605750   1.826767  46.597586      0.022066     57.993905      0.003298      0.164309      0.002918      0.386400  89.0  83.0  40.0  14.0
# 4   0.261753   0.195657   0.721794     -0.195947     -0.677041     1.0     2.0  646.745868  590.821024  650.519613  606.459678           -73.570409 -23.618769   0.029079            469.178802                7827.098153               4.374142e+16   3.392176  260.727425   16.110807  54063.675421   1.958295  46.594699      0.015075     57.946717      0.003670      0.164172      0.003220      0.386388  89.0  83.0  40.0  14.0
#
# [5 rows x 103 columns]

# %%
def preprocessing(df):
  num_cols = df.select_dtypes(include='number').columns
  df[num_cols] = df[num_cols].fillna(df[num_cols].mean())
  df['c_object_type']=df['c_object_type'].fillna(df['c_object_type'].mode()[0])
  mapping = {
    'UNKOWN': 1,
    'TBA': 2,
    'ROCKET BODY': 3,
    'PAYLOAD':4,
    'DEBRIS':5
  }
  df['c_object_type']=df['c_object_type'].map(mapping)
  return df

# %%
def filtering (df):
  train=df[df['time_to_tca']>=2]
  train = train.sort_values(['event_id', 'time_to_tca'], ascending=[True, False])
  feature=train.drop(columns=['event_id','risk'])
  groups = train.groupby("event_id")
  return feature,groups

# %%
def feature_engineering(groups, feature):
    features = []
    targets = []

    for eid, g in groups:
        g = g.sort_values('time_to_tca', ascending=False)

        first = g.iloc[0]
        last  = g.iloc[-1]
        feat = {}

        targets.append(last['risk'])

        dt = first['time_to_tca'] - last['time_to_tca']
        dt = max(dt, 1e-6)

        for col in feature:
            if col in ['mission_id', 'c_object_type']:
                feat[col + "_last"] = last[col]
                continue

            feat[col + "_last"] = last[col]
            feat[col + "_mean"] = g[col].mean()
            feat[col + "_std"]  = g[col].std()
            feat[col + "_min"]  = g[col].min()
            feat[col + "_max"]  = g[col].max()
            feat[col + "_delta"] = last[col] - first[col]
            feat[col + "_slope"] = (last[col] - first[col]) / dt

        features.append(feat)

    X = pd.DataFrame(features)
    y = np.array(targets)

    return X, y

# %%
df_test=preprocessing(df_test)
df_train=preprocessing(df_train)

# %%
f,g=filtering(df_test)
m,n=filtering(df_train)

# %%
X_test,y_test=feature_engineering(g,f)
X_train,y_train=feature_engineering(n,m)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import numpy as np
import pandas as pd

print("inf---------------------",np.isinf(X_train).sum())

print("none---------------------",np.isnan(X_train).sum())

print("max----------------------",np.max(np.abs(X_train)))
# Out:
# inf--------------------- time_to_tca_last                   0
# time_to_tca_mean                   0
# time_to_tca_std                    0
# time_to_tca_min                    0
# time_to_tca_max                    0
# time_to_tca_delta                  0
# time_to_tca_slope                  0
# mission_id_last                    0
# max_risk_estimate_last             0
# max_risk_estimate_mean             0
# max_risk_estimate_std              0
# max_risk_estimate_min              0
# max_risk_estimate_max              0
# max_risk_estimate_delta            0
# max_risk_estimate_slope            0
# max_risk_scaling_last              0
# max_risk_scaling_mean              0
# max_risk_scaling_std               0
# max_risk_scaling_min               0
# max_risk_scaling_max               0
# max_risk_scaling_delta             0
# max_risk_scaling_slope             0
# miss_distance_last                 0
# miss_distance_mean                 0
# miss_distance_std                  0
# miss_distance_min                  0
# miss_distance_max                  0
# miss_distance_delta                0
# miss_distance_slope                0
# relative_speed_last                0
# relative_speed_mean                0
# relative_speed_std                 0
# relative_speed_min                 0
# relative_speed_max                 0
# relative_speed_delta               0
# relative_speed_slope               0
# relative_position_r_last           0
# relative_position_r_mean           0
# relative_position_r_std            0
# relative_position_r_min            0
# relative_position_r_max            0
# relative_position_r_delta          0
# relative_position_r_slope          0
# relative_position_t_last           0
# relative_position_t_mean           0
# relative_position_t_std            0
# relative_position_t_min            0
# relative_position_t_max            0
# relative_position_t_delta          0
# relative_position_t_slope          0
# relative_position_n_last           0
# relative_position_n_mean           0
# relative_position_n_std            0
# relative_position_n_min            0
# relative_position_n_max            0
# relative_position_n_delta          0
# relative_position_n_slope          0
# relative_velocity_r_last           0
# relative_velocity_r_mean           0
# relative_velocity_r_std            0
# relative_velocity_r_min            0
# relative_velocity_r_max            0
# relative_velocity_r_delta          0
# relative_velocity_r_slope          0
# relative_velocity_t_last           0
# relative_velocity_t_mean           0
# relative_velocity_t_std            0
# relative_velocity_t_min            0
# relative_velocity_t_max            0
# relative_velocity_t_delta          0
# relative_velocity_t_slope          0
# relative_velocity_n_last           0
# relative_velocity_n_mean           0
# relative_velocity_n_std            0
# relative_velocity_n_min            0
# relative_velocity_n_max            0
# relative_velocity_n_delta          0
# relative_velocity_n_slope          0
# t_time_lastob_start_last           0
# t_time_lastob_start_mean           0
# t_time_lastob_start_std            0
# t_time_lastob_start_min            0
# t_time_lastob_start_max            0
# t_time_lastob_start_delta          0
# t_time_lastob_start_slope          0
# t_time_lastob_end_last             0
# t_time_lastob_end_mean             0
# t_time_lastob_end_std              0
# t_time_lastob_end_min              0
# t_time_lastob_end_max              0
# t_time_lastob_end_delta            0
# t_time_lastob_end_slope            0
# t_recommended_od_span_last         0
# t_recommended_od_span_mean         0
# t_recommended_od_span_std          0
# t_recommended_od_span_min          0
# t_recommended_od_span_max          0
# t_recommended_od_span_delta        0
# t_recommended_od_span_slope        0
# t_actual_od_span_last              0
# t_actual_od_span_mean              0
# t_actual_od_span_std               0
# t_actual_od_span_min               0
# t_actual_od_span_max               0
# t_actual_od_span_delta             0
# t_actual_od_span_slope             0
# t_obs_available_last               0
# t_obs_available_mean               0
# t_obs_available_std                0
# t_obs_available_min                0
# t_obs_available_max                0
# t_obs_available_delta              0
# t_obs_available_slope              0
# t_obs_used_last                    0
# t_obs_used_mean                    0
# t_obs_used_std                     0
# t_obs_used_min                     0
# t_obs_used_max                     0
# t_obs_used_delta                   0
# t_obs_used_slope                   0
# t_residuals_accepted_last          0
# t_residuals_accepted_mean          0
# t_residuals_accepted_std           0
# t_residuals_accepted_min           0
# t_residuals_accepted_max           0
# t_residuals_accepted_delta         0
# t_residuals_accepted_slope         0
# t_weighted_rms_last                0
# t_weighted_rms_mean                0
# t_weighted_rms_std                 0
# t_weighted_rms_min                 0
# t_weighted_rms_max                 0
# t_weighted_rms_delta               0
# t_weighted_rms_slope               0
# t_rcs_estimate_last                0
# t_rcs_estimate_mean                0
# t_rcs_estimate_std                 0
# t_rcs_estimate_min                 0
# t_rcs_estimate_max                 0
# t_rcs_estimate_delta               0
# t_rcs_estimate_slope               0
# t_cd_area_over_mass_last           0
# t_cd_area_over_mass_mean           0
# t_cd_area_over_mass_std            0
# t_cd_area_over_mass_min            0
# t_cd_area_over_mass_max            0
# t_cd_area_over_mass_delta          0
# t_cd_area_over_mass_slope          0
# t_cr_area_over_mass_last           0
# t_cr_area_over_mass_mean           0
# t_cr_area_over_mass_std            0
# t_cr_area_over_mass_min            0
# t_cr_area_over_mass_max            0
# t_cr_area_over_mass_delta          0
# t_cr_area_over_mass_slope          0
# t_sedr_last                        0
# t_sedr_mean                        0
# t_sedr_std                         0
# t_sedr_min                         0
# t_sedr_max                         0
# t_sedr_delta                       0
# t_sedr_slope                       0
# t_j2k_sma_last                     0
# t_j2k_sma_mean                     0
# t_j2k_sma_std                      0
# t_j2k_sma_min                      0
# t_j2k_sma_max                      0
# t_j2k_sma_delta                    0
# t_j2k_sma_slope                    0
# t_j2k_ecc_last                     0
# t_j2k_ecc_mean                     0
# t_j2k_ecc_std                      0
# t_j2k_ecc_min                      0
# t_j2k_ecc_max                      0
# t_j2k_ecc_delta                    0
# t_j2k_ecc_slope                    0
# t_j2k_inc_last                     0
# t_j2k_inc_mean                     0
# t_j2k_inc_std                      0
# t_j2k_inc_min                      0
# t_j2k_inc_max                      0
# t_j2k_inc_delta                    0
# t_j2k_inc_slope                    0
# t_ct_r_last                        0
# t_ct_r_mean                        0
# t_ct_r_std                         0
# t_ct_r_min                         0
# t_ct_r_max                         0
# t_ct_r_delta                       0
# t_ct_r_slope                       0
# t_cn_r_last                        0
# t_cn_r_mean                        0
# t_cn_r_std                         0
# t_cn_r_min                         0
# t_cn_r_max                         0
# t_cn_r_delta                       0
# t_cn_r_slope                       0
# t_cn_t_last                        0
# t_cn_t_mean                        0
# t_cn_t_std                         0
# t_cn_t_min                         0
# t_cn_t_max                         0
# t_cn_t_delta                       0
# t_cn_t_slope                       0
# t_crdot_r_last                     0
# t_crdot_r_mean                     0
# t_crdot_r_std                      0
# t_crdot_r_min                      0
# t_crdot_r_max                      0
# t_crdot_r_delta                    0
# t_crdot_r_slope                    0
# t_crdot_t_last                     0
# t_crdot_t_mean                     0
# t_crdot_t_std                      0
# t_crdot_t_min                      0
# t_crdot_t_max                      0
# t_crdot_t_delta                    0
# t_crdot_t_slope                    0
# t_crdot_n_last                     0
# t_crdot_n_mean                     0
# t_crdot_n_std                      0
# t_crdot_n_min                      0
# t_crdot_n_max                      0
# t_crdot_n_delta                    0
# t_crdot_n_slope                    0
# t_ctdot_r_last                     0
# t_ctdot_r_mean                     0
# t_ctdot_r_std                      0
# t_ctdot_r_min                      0
# t_ctdot_r_max                      0
# t_ctdot_r_delta                    0
# t_ctdot_r_slope                    0
# t_ctdot_t_last                     0
# t_ctdot_t_mean                     0
# t_ctdot_t_std                      0
# t_ctdot_t_min                      0
# t_ctdot_t_max                      0
# t_ctdot_t_delta                    0
# t_ctdot_t_slope                    0
# t_ctdot_n_last                     0
# t_ctdot_n_mean                     0
# t_ctdot_n_std                      0
# t_ctdot_n_min                      0
# t_ctdot_n_max                      0
# t_ctdot_n_delta                    0
# t_ctdot_n_slope                    0
# t_ctdot_rdot_last                  0
# t_ctdot_rdot_mean                  0
# t_ctdot_rdot_std                   0
# t_ctdot_rdot_min                   0
# t_ctdot_rdot_max                   0
# t_ctdot_rdot_delta                 0
# t_ctdot_rdot_slope                 0
# t_cndot_r_last                     0
# t_cndot_r_mean                     0
# t_cndot_r_std                      0
# t_cndot_r_min                      0
# t_cndot_r_max                      0
# t_cndot_r_delta                    0
# t_cndot_r_slope                    0
# t_cndot_t_last                     0
# t_cndot_t_mean                     0
# t_cndot_t_std                      0
# t_cndot_t_min                      0
# t_cndot_t_max                      0
# t_cndot_t_delta                    0
# t_cndot_t_slope                    0
# t_cndot_n_last                     0
# t_cndot_n_mean                     0
# t_cndot_n_std                      0
# t_cndot_n_min                      0
# t_cndot_n_max                      0
# t_cndot_n_delta                    0
# t_cndot_n_slope                    0
# t_cndot_rdot_last                  0
# t_cndot_rdot_mean                  0
# t_cndot_rdot_std                   0
# t_cndot_rdot_min                   0
# t_cndot_rdot_max                   0
# t_cndot_rdot_delta                 0
# t_cndot_rdot_slope                 0
# t_cndot_tdot_last                  0
# t_cndot_tdot_mean                  0
# t_cndot_tdot_std                   0
# t_cndot_tdot_min                   0
# t_cndot_tdot_max                   0
# t_cndot_tdot_delta                 0
# t_cndot_tdot_slope                 0
# c_object_type_last                 0
# c_time_lastob_start_last           0
# c_time_lastob_start_mean           0
# c_time_lastob_start_std            0
# c_time_lastob_start_min            0
# c_time_lastob_start_max            0
# c_time_lastob_start_delta          0
# c_time_lastob_start_slope          0
# c_time_lastob_end_last             0
# c_time_lastob_end_mean             0
# c_time_lastob_end_std              0
# c_time_lastob_end_min              0
# c_time_lastob_end_max              0
# c_time_lastob_end_delta            0
# c_time_lastob_end_slope            0
# c_recommended_od_span_last         0
# c_recommended_od_span_mean         0
# c_recommended_od_span_std          0
# c_recommended_od_span_min          0
# c_recommended_od_span_max          0
# c_recommended_od_span_delta        0
# c_recommended_od_span_slope        0
# c_actual_od_span_last              0
# c_actual_od_span_mean              0
# c_actual_od_span_std               0
# c_actual_od_span_min               0
# c_actual_od_span_max               0
# c_actual_od_span_delta             0
# c_actual_od_span_slope             0
# c_obs_available_last               0
# c_obs_available_mean               0
# c_obs_available_std                0
# c_obs_available_min                0
# c_obs_available_max                0
# c_obs_available_delta              0
# c_obs_available_slope              0
# c_obs_used_last                    0
# c_obs_used_mean                    0
# c_obs_used_std                     0
# c_obs_used_min                     0
# c_obs_used_max                     0
# c_obs_used_delta                   0
# c_obs_used_slope                   0
# c_residuals_accepted_last          0
# c_residuals_accepted_mean          0
# c_residuals_accepted_std           0
# c_residuals_accepted_min           0
# c_residuals_accepted_max           0
# c_residuals_accepted_delta         0
# c_residuals_accepted_slope         0
# c_weighted_rms_last                0
# c_weighted_rms_mean                0
# c_weighted_rms_std                 0
# c_weighted_rms_min                 0
# c_weighted_rms_max                 0
# c_ctdot_t_slope                    0
# c_ctdot_n_last                     0
# c_ctdot_n_mean                     0
# c_ctdot_n_std                      0
# c_ctdot_n_min                      0
# c_ctdot_n_max                      0
# c_ctdot_n_delta                    0
# c_ctdot_n_slope                    0
# c_ctdot_rdot_last                  0
# c_ctdot_rdot_mean                  0
# c_ctdot_rdot_std                   0
# c_ctdot_rdot_min                   0
# c_ctdot_rdot_max                   0
# c_ctdot_rdot_delta                 0
# c_ctdot_rdot_slope                 0
# c_cndot_r_last                     0
# c_cndot_r_mean                     0
# c_cndot_r_std                      0
# c_cndot_r_min                      0
# c_cndot_r_max                      0
# c_cndot_r_delta                    0
# c_cndot_r_slope                    0
# c_cndot_t_last                     0
# c_cndot_t_mean                     0
# c_cndot_t_std                      0
# c_cndot_t_min                      0
# c_cndot_t_max                      0
# c_cndot_t_delta                    0
# c_cndot_t_slope                    0
# c_cndot_n_last                     0
# c_cndot_n_mean                     0
# c_cndot_n_std                      0
# c_cndot_n_min                      0
# c_cndot_n_max                      0
# c_cndot_n_delta                    0
# c_cndot_n_slope                    0
# c_cndot_rdot_last                  0
# c_cndot_rdot_mean                  0
# c_cndot_rdot_std                   0
# c_cndot_rdot_min                   0
# c_cndot_rdot_max                   0
# c_cndot_rdot_delta                 0
# c_cndot_rdot_slope                 0
# c_cndot_tdot_last                  0
# c_cndot_tdot_mean                  0
# c_cndot_tdot_std                   0
# c_cndot_tdot_min                   0
# c_cndot_tdot_max                   0
# c_cndot_tdot_delta                 0
# c_cndot_tdot_slope                 0
# t_span_last                        0
# t_span_mean                        0
# t_span_std                         0
# t_span_min                         0
# t_span_max                         0
# t_span_delta                       0
# t_span_slope                       0
# c_span_last                        0
# c_span_mean                        0
# c_span_std                         0
# c_span_min                         0
# c_span_max                         0
# c_span_delta                       0
# c_span_slope                       0
# t_h_apo_last                       0
# t_h_apo_mean                       0
# t_h_apo_std                        0
# t_h_apo_min                        0
# t_h_apo_max                        0
# t_h_apo_delta                      0
# t_h_apo_slope                      0
# t_h_per_last                       0
# t_h_per_mean                       0
# t_h_per_std                        0
# t_h_per_min                        0
# t_h_per_max                        0
# t_h_per_delta                      0
# t_h_per_slope                      0
# c_h_apo_last                       0
# c_h_apo_mean                       0
# c_h_apo_std                        0
# c_h_apo_min                        0
# c_h_apo_max                        0
# c_h_apo_delta                      0
# c_h_apo_slope                      0
# c_h_per_last                       0
# c_h_per_mean                       0
# c_h_per_std                        0
# c_h_per_min                        0
# c_h_per_max                        0
# c_h_per_delta                      0
# c_h_per_slope                      0
# geocentric_latitude_last           0
# geocentric_latitude_mean           0
# geocentric_latitude_std            0
# geocentric_latitude_min            0
# geocentric_latitude_max            0
# geocentric_latitude_delta          0
# geocentric_latitude_slope          0
# azimuth_last                       0
# azimuth_mean                       0
# azimuth_std                        0
# azimuth_min                        0
# azimuth_max                        0
# azimuth_delta                      0
# azimuth_slope                      0
# elevation_last                     0
# elevation_mean                     0
# elevation_std                      0
# elevation_min                      0
# elevation_max                      0
# elevation_delta                    0
# elevation_slope                    0
# mahalanobis_distance_last          0
# mahalanobis_distance_mean          0
# mahalanobis_distance_std           0
# mahalanobis_distance_min           0
# mahalanobis_distance_max           0
# mahalanobis_distance_delta         0
# mahalanobis_distance_slope         0
# t_position_covariance_det_last     0
# t_position_covariance_det_mean     0
# t_position_covariance_det_std      0
# t_position_covariance_det_min      0
# t_position_covariance_det_max      0
# t_position_covariance_det_delta    0
# t_position_covariance_det_slope    0
# c_position_covariance_det_last     0
# c_position_covariance_det_mean     0
# c_position_covariance_det_std      0
# c_position_covariance_det_min      0
# c_position_covariance_det_max      0
# c_position_covariance_det_delta    0
# c_position_covariance_det_slope    0
# t_sigma_r_last                     0
# t_sigma_r_mean                     0
# t_sigma_r_std                      0
# t_sigma_r_min                      0
# t_sigma_r_max                      0
# t_sigma_r_delta                    0
# t_sigma_r_slope                    0
# c_sigma_r_last                     0
# c_sigma_r_mean                     0
# c_sigma_r_std                      0
# c_sigma_r_min                      0
# c_sigma_r_max                      0
# c_sigma_r_delta                    0
# c_sigma_r_slope                    0
# t_sigma_t_last                     0
# t_sigma_t_mean                     0
# t_sigma_t_std                      0
# t_sigma_t_min                      0
# t_sigma_t_max                      0
# t_sigma_t_delta                    0
# t_sigma_t_slope                    0
# c_sigma_t_last                     0
# c_sigma_t_mean                     0
# c_sigma_t_std                      0
# c_sigma_t_min                      0
# c_sigma_t_max                      0
# c_sigma_t_delta                    0
# c_sigma_t_slope                    0
# t_sigma_n_last                     0
# t_sigma_n_mean                     0
# t_sigma_n_std                      0
# t_sigma_n_min                      0
# t_sigma_n_max                      0
# t_sigma_n_delta                    0
# t_sigma_n_slope                    0
# c_sigma_n_last                     0
# c_sigma_n_mean                     0
# c_sigma_n_std                      0
# c_sigma_n_min                      0
# c_sigma_n_max                      0
# c_sigma_n_delta                    0
# c_sigma_n_slope                    0
# t_sigma_rdot_last                  0
# t_sigma_rdot_mean                  0
# t_sigma_rdot_std                   0
# t_sigma_rdot_min                   0
# t_sigma_rdot_max                   0
# t_sigma_rdot_delta                 0
# t_sigma_rdot_slope                 0
# c_sigma_rdot_last                  0
# c_sigma_rdot_mean                  0
# c_sigma_rdot_std                   0
# c_sigma_rdot_min                   0
# c_sigma_rdot_max                   0
# c_sigma_rdot_delta                 0
# c_sigma_rdot_slope                 0
# t_sigma_tdot_last                  0
# t_sigma_tdot_mean                  0
# t_sigma_tdot_std                   0
# t_sigma_tdot_min                   0
# t_sigma_tdot_max                   0
# t_sigma_tdot_delta                 0
# t_sigma_tdot_slope                 0
# c_sigma_tdot_last                  0
# c_sigma_tdot_mean                  0
# c_sigma_tdot_std                   0
# c_sigma_tdot_min                   0
# c_sigma_tdot_max                   0
# c_sigma_tdot_delta                 0
# c_sigma_tdot_slope                 0
# t_sigma_ndot_last                  0
# t_sigma_ndot_mean                  0
# t_sigma_ndot_std                   0
# t_sigma_ndot_min                   0
# t_sigma_ndot_max                   0
# t_sigma_ndot_delta                 0
# t_sigma_ndot_slope                 0
# c_sigma_ndot_last                  0
# c_sigma_ndot_mean                  0
# c_sigma_ndot_std                   0
# c_sigma_ndot_min                   0
# c_sigma_ndot_max                   0
# c_sigma_ndot_delta                 0
# c_sigma_ndot_slope                 0
# F10_last                           0
# F10_mean                           0
# F10_std                            0
# F10_min                            0
# F10_max                            0
# F10_delta                          0
# F10_slope                          0
# F3M_last                           0
# F3M_mean                           0
# F3M_std                            0
# F3M_min                            0
# F3M_max                            0
# F3M_delta                          0
# F3M_slope                          0
# SSN_last                           0
# SSN_mean                           0
# SSN_std                            0
# SSN_min                            0
# SSN_max                            0
# SSN_delta                          0
# SSN_slope                          0
# AP_last                            0
# AP_mean                            0
# AP_std                             0
# AP_min                             0
# AP_max                             0
# AP_delta                           0
# AP_slope                           0
# dtype: int64
# none--------------------- time_to_tca_last                      0
# time_to_tca_mean                      0
# time_to_tca_std                     497
# time_to_tca_min                       0
# time_to_tca_max                       0
# time_to_tca_delta                     0
# time_to_tca_slope                     0
# mission_id_last                       0
# max_risk_estimate_last                0
# max_risk_estimate_mean                0
# max_risk_estimate_std               497
# max_risk_estimate_min                 0
# max_risk_estimate_max                 0
# max_risk_estimate_delta               0
# max_risk_estimate_slope               0
# max_risk_scaling_last                 0
# max_risk_scaling_mean                 0
# max_risk_scaling_std                497
# max_risk_scaling_min                  0
# max_risk_scaling_max                  0
# max_risk_scaling_delta                0
# max_risk_scaling_slope                0
# miss_distance_last                    0
# miss_distance_mean                    0
# miss_distance_std                   497
# miss_distance_min                     0
# miss_distance_max                     0
# miss_distance_delta                   0
# miss_distance_slope                   0
# relative_speed_last                   0
# relative_speed_mean                   0
# relative_speed_std                  497
# relative_speed_min                    0
# relative_speed_max                    0
# relative_speed_delta                  0
# relative_speed_slope                  0
# relative_position_r_last              0
# relative_position_r_mean              0
# relative_position_r_std             497
# relative_position_r_min               0
# relative_position_r_max               0
# relative_position_r_delta             0
# relative_position_r_slope             0
# relative_position_t_last              0
# relative_position_t_mean              0
# relative_position_t_std             497
# relative_position_t_min               0
# relative_position_t_max               0
# relative_position_t_delta             0
# relative_position_t_slope             0
# relative_position_n_last              0
# relative_position_n_mean              0
# relative_position_n_std             497
# relative_position_n_min               0
# relative_position_n_max               0
# relative_position_n_delta             0
# relative_position_n_slope             0
# relative_velocity_r_last              0
# relative_velocity_r_mean              0
# relative_velocity_r_std             497
# relative_velocity_r_min               0
# relative_velocity_r_max               0
# relative_velocity_r_delta             0
# relative_velocity_r_slope             0
# relative_velocity_t_last              0
# relative_velocity_t_mean              0
# relative_velocity_t_std             497
# relative_velocity_t_min               0
# relative_velocity_t_max               0
# relative_velocity_t_delta             0
# relative_velocity_t_slope             0
# relative_velocity_n_last              0
# relative_velocity_n_mean              0
# relative_velocity_n_std             497
# relative_velocity_n_min               0
# relative_velocity_n_max               0
# relative_velocity_n_delta             0
# relative_velocity_n_slope             0
# t_time_lastob_start_last              0
# t_time_lastob_start_mean              0
# t_time_lastob_start_std             497
# t_time_lastob_start_min               0
# t_time_lastob_start_max               0
# t_time_lastob_start_delta             0
# t_time_lastob_start_slope             0
# t_time_lastob_end_last                0
# t_time_lastob_end_mean                0
# t_time_lastob_end_std               497
# t_time_lastob_end_min                 0
# t_time_lastob_end_max                 0
# t_time_lastob_end_delta               0
# t_time_lastob_end_slope               0
# t_recommended_od_span_last            0
# t_recommended_od_span_mean            0
# t_recommended_od_span_std           497
# t_recommended_od_span_min             0
# t_recommended_od_span_max             0
# t_recommended_od_span_delta           0
# t_recommended_od_span_slope           0
# t_actual_od_span_last                 0
# t_actual_od_span_mean                 0
# t_actual_od_span_std                497
# t_actual_od_span_min                  0
# t_actual_od_span_max                  0
# t_actual_od_span_delta                0
# t_actual_od_span_slope                0
# t_obs_available_last                  0
# t_obs_available_mean                  0
# t_obs_available_std                 497
# t_obs_available_min                   0
# t_obs_available_max                   0
# t_obs_available_delta                 0
# t_obs_available_slope                 0
# t_obs_used_last                       0
# t_obs_used_mean                       0
# t_obs_used_std                      497
# t_obs_used_min                        0
# t_obs_used_max                        0
# t_obs_used_delta                      0
# t_obs_used_slope                      0
# t_residuals_accepted_last             0
# t_residuals_accepted_mean             0
# t_residuals_accepted_std            497
# t_residuals_accepted_min              0
# t_residuals_accepted_max              0
# t_residuals_accepted_delta            0
# t_residuals_accepted_slope            0
# t_weighted_rms_last                   0
# t_weighted_rms_mean                   0
# t_weighted_rms_std                  497
# t_weighted_rms_min                    0
# t_weighted_rms_max                    0
# t_weighted_rms_delta                  0
# t_weighted_rms_slope                  0
# t_rcs_estimate_last                   0
# t_rcs_estimate_mean                   0
# t_rcs_estimate_std                  497
# t_rcs_estimate_min                    0
# t_rcs_estimate_max                    0
# t_rcs_estimate_delta                  0
# t_rcs_estimate_slope                  0
# t_cd_area_over_mass_last              0
# t_cd_area_over_mass_mean              0
# t_cd_area_over_mass_std             497
# t_cd_area_over_mass_min               0
# t_cd_area_over_mass_max               0
# t_cd_area_over_mass_delta             0
# t_cd_area_over_mass_slope             0
# t_cr_area_over_mass_last              0
# t_cr_area_over_mass_mean              0
# t_cr_area_over_mass_std             497
# t_cr_area_over_mass_min               0
# t_cr_area_over_mass_max               0
# t_cr_area_over_mass_delta             0
# t_cr_area_over_mass_slope             0
# t_sedr_last                           0
# t_sedr_mean                           0
# t_sedr_std                          497
# t_sedr_min                            0
# t_sedr_max                            0
# t_sedr_delta                          0
# t_sedr_slope                          0
# t_j2k_sma_last                        0
# t_j2k_sma_mean                        0
# t_j2k_sma_std                       497
# t_j2k_sma_min                         0
# t_j2k_sma_max                         0
# t_j2k_sma_delta                       0
# t_j2k_sma_slope                       0
# t_j2k_ecc_last                        0
# t_j2k_ecc_mean                        0
# t_j2k_ecc_std                       497
# t_j2k_ecc_min                         0
# t_j2k_ecc_max                         0
# t_j2k_ecc_delta                       0
# t_j2k_ecc_slope                       0
# t_j2k_inc_last                        0
# t_j2k_inc_mean                        0
# t_j2k_inc_std                       497
# t_j2k_inc_min                         0
# t_j2k_inc_max                         0
# t_j2k_inc_delta                       0
# t_j2k_inc_slope                       0
# t_ct_r_last                           0
# t_ct_r_mean                           0
# t_ct_r_std                          497
# t_ct_r_min                            0
# t_ct_r_max                            0
# t_ct_r_delta                          0
# t_ct_r_slope                          0
# t_cn_r_last                           0
# t_cn_r_mean                           0
# t_cn_r_std                          497
# t_cn_r_min                            0
# t_cn_r_max                            0
# t_cn_r_delta                          0
# t_cn_r_slope                          0
# t_cn_t_last                           0
# t_cn_t_mean                           0
# t_cn_t_std                          497
# t_cn_t_min                            0
# t_cn_t_max                            0
# t_cn_t_delta                          0
# t_cn_t_slope                          0
# t_crdot_r_last                        0
# t_crdot_r_mean                        0
# t_crdot_r_std                       497
# t_crdot_r_min                         0
# t_crdot_r_max                         0
# t_crdot_r_delta                       0
# t_crdot_r_slope                       0
# t_crdot_t_last                        0
# t_crdot_t_mean                        0
# t_crdot_t_std                       497
# t_crdot_t_min                         0
# t_crdot_t_max                         0
# t_crdot_t_delta                       0
# t_crdot_t_slope                       0
# t_crdot_n_last                        0
# t_crdot_n_mean                        0
# t_crdot_n_std                       497
# t_crdot_n_min                         0
# t_crdot_n_max                         0
# t_crdot_n_delta                       0
# t_crdot_n_slope                       0
# t_ctdot_r_last                        0
# t_ctdot_r_mean                        0
# t_ctdot_r_std                       497
# t_ctdot_r_min                         0
# t_ctdot_r_max                         0
# t_ctdot_r_delta                       0
# t_ctdot_r_slope                       0
# t_ctdot_t_last                        0
# t_ctdot_t_mean                        0
# t_ctdot_t_std                       497
# t_ctdot_t_min                         0
# t_ctdot_t_max                         0
# t_ctdot_t_delta                       0
# t_ctdot_t_slope                       0
# t_ctdot_n_last                        0
# t_ctdot_n_mean                        0
# t_ctdot_n_std                       497
# t_ctdot_n_min                         0
# t_ctdot_n_max                         0
# t_ctdot_n_delta                       0
# t_ctdot_n_slope                       0
# t_ctdot_rdot_last                     0
# t_ctdot_rdot_mean                     0
# t_ctdot_rdot_std                    497
# t_ctdot_rdot_min                      0
# t_ctdot_rdot_max                      0
# t_ctdot_rdot_delta                    0
# t_ctdot_rdot_slope                    0
# t_cndot_r_last                        0
# t_cndot_r_mean                        0
# t_cndot_r_std                       497
# t_cndot_r_min                         0
# t_cndot_r_max                         0
# t_cndot_r_delta                       0
# t_cndot_r_slope                       0
# t_cndot_t_last                        0
# t_cndot_t_mean                        0
# t_cndot_t_std                       497
# t_cndot_t_min                         0
# t_cndot_t_max                         0
# t_cndot_t_delta                       0
# t_cndot_t_slope                       0
# t_cndot_n_last                        0
# t_cndot_n_mean                        0
# t_cndot_n_std                       497
# t_cndot_n_min                         0
# t_cndot_n_max                         0
# t_cndot_n_delta                       0
# t_cndot_n_slope                       0
# t_cndot_rdot_last                     0
# t_cndot_rdot_mean                     0
# t_cndot_rdot_std                    497
# t_cndot_rdot_min                      0
# t_cndot_rdot_max                      0
# t_cndot_rdot_delta                    0
# t_cndot_rdot_slope                    0
# t_cndot_tdot_last                     0
# t_cndot_tdot_mean                     0
# t_cndot_tdot_std                    497
# t_cndot_tdot_min                      0
# t_cndot_tdot_max                      0
# t_cndot_tdot_delta                    0
# t_cndot_tdot_slope                    0
# c_object_type_last                 3866
# c_time_lastob_start_last              0
# c_time_lastob_start_mean              0
# c_time_lastob_start_std             497
# c_time_lastob_start_min               0
# c_time_lastob_start_max               0
# c_time_lastob_start_delta             0
# c_time_lastob_start_slope             0
# c_time_lastob_end_last                0
# c_time_lastob_end_mean                0
# c_time_lastob_end_std               497
# c_time_lastob_end_min                 0
# c_time_lastob_end_max                 0
# c_time_lastob_end_delta               0
# c_time_lastob_end_slope               0
# t_h_apo_delta                         0
# t_h_apo_slope                         0
# t_h_per_last                          0
# t_h_per_mean                          0
# t_h_per_std                         497
# t_h_per_min                           0
# t_h_per_max                           0
# t_h_per_delta                         0
# t_h_per_slope                         0
# c_h_apo_last                          0
# c_h_apo_mean                          0
# c_h_apo_std                         497
# c_h_apo_min                           0
# c_h_apo_max                           0
# c_h_apo_delta                         0
# c_h_apo_slope                         0
# c_h_per_last                          0
# c_h_per_mean                          0
# c_h_per_std                         497
# c_h_per_min                           0
# c_h_per_max                           0
# c_h_per_delta                         0
# c_h_per_slope                         0
# geocentric_latitude_last              0
# geocentric_latitude_mean              0
# geocentric_latitude_std             497
# geocentric_latitude_min               0
# geocentric_latitude_max               0
# geocentric_latitude_delta             0
# geocentric_latitude_slope             0
# azimuth_last                          0
# azimuth_mean                          0
# azimuth_std                         497
# azimuth_min                           0
# azimuth_max                           0
# azimuth_delta                         0
# azimuth_slope                         0
# elevation_last                        0
# elevation_mean                        0
# elevation_std                       497
# elevation_min                         0
# elevation_max                         0
# elevation_delta                       0
# elevation_slope                       0
# mahalanobis_distance_last             0
# mahalanobis_distance_mean             0
# mahalanobis_distance_std            497
# mahalanobis_distance_min              0
# mahalanobis_distance_max              0
# mahalanobis_distance_delta            0
# mahalanobis_distance_slope            0
# t_position_covariance_det_last        0
# t_position_covariance_det_mean        0
# t_position_covariance_det_std       497
# t_position_covariance_det_min         0
# t_position_covariance_det_max         0
# t_position_covariance_det_delta       0
# t_position_covariance_det_slope       0
# c_position_covariance_det_last        0
# c_position_covariance_det_mean        0
# c_position_covariance_det_std       497
# c_position_covariance_det_min         0
# c_position_covariance_det_max         0
# c_position_covariance_det_delta       0
# c_position_covariance_det_slope       0
# t_sigma_r_last                        0
# t_sigma_r_mean                        0
# t_sigma_r_std                       497
# t_sigma_r_min                         0
# t_sigma_r_max                         0
# t_sigma_r_delta                       0
# t_sigma_r_slope                       0
# c_sigma_r_last                        0
# c_sigma_r_mean                        0
# c_sigma_r_std                       497
# c_sigma_r_min                         0
# c_sigma_r_max                         0
# c_sigma_r_delta                       0
# c_sigma_r_slope                       0
# t_sigma_t_last                        0
# t_sigma_t_mean                        0
# t_sigma_t_std                       497
# t_sigma_t_min                         0
# t_sigma_t_max                         0
# t_sigma_t_delta                       0
# t_sigma_t_slope                       0
# c_sigma_t_last                        0
# c_sigma_t_mean                        0
# c_sigma_t_std                       497
# c_sigma_t_min                         0
# c_sigma_t_max                         0
# c_sigma_t_delta                       0
# c_sigma_t_slope                       0
# t_sigma_n_last                        0
# t_sigma_n_mean                        0
# t_sigma_n_std                       497
# t_sigma_n_min                         0
# t_sigma_n_max                         0
# t_sigma_n_delta                       0
# t_sigma_n_slope                       0
# c_sigma_n_last                        0
# c_sigma_n_mean                        0
# c_sigma_n_std                       497
# c_sigma_n_min                         0
# c_sigma_n_max                         0
# c_sigma_n_delta                       0
# c_sigma_n_slope                       0
# t_sigma_rdot_last                     0
# t_sigma_rdot_mean                     0
# t_sigma_rdot_std                    497
# t_sigma_rdot_min                      0
# t_sigma_rdot_max                      0
# t_sigma_rdot_delta                    0
# t_sigma_rdot_slope                    0
# c_sigma_rdot_last                     0
# c_sigma_rdot_mean                     0
# c_sigma_rdot_std                    497
# c_sigma_rdot_min                      0
# c_sigma_rdot_max                      0
# c_sigma_rdot_delta                    0
# c_sigma_rdot_slope                    0
# t_sigma_tdot_last                     0
# t_sigma_tdot_mean                     0
# t_sigma_tdot_std                    497
# t_sigma_tdot_min                      0
# t_sigma_tdot_max                      0
# t_sigma_tdot_delta                    0
# t_sigma_tdot_slope                    0
# c_sigma_tdot_last                     0
# c_sigma_tdot_mean                     0
# c_sigma_tdot_std                    497
# c_sigma_tdot_min                      0
# c_sigma_tdot_max                      0
# c_sigma_tdot_delta                    0
# c_sigma_tdot_slope                    0
# t_sigma_ndot_last                     0
# t_sigma_ndot_mean                     0
# t_sigma_ndot_std                    497
# t_sigma_ndot_min                      0
# t_sigma_ndot_max                      0
# t_sigma_ndot_delta                    0
# t_sigma_ndot_slope                    0
# c_sigma_ndot_last                     0
# c_sigma_ndot_mean                     0
# c_sigma_ndot_std                    497
# c_sigma_ndot_min                      0
# c_sigma_ndot_max                      0
# c_sigma_ndot_delta                    0
# c_sigma_ndot_slope                    0
# F10_last                              0
# F10_mean                              0
# F10_std                             497
# F10_min                               0
# F10_max                               0
# F10_delta                             0
# F10_slope                             0
# F3M_last                              0
# F3M_mean                              0
# F3M_std                             497
# F3M_min                               0
# F3M_max                               0
# F3M_delta                             0
# F3M_slope                             0
# SSN_last                              0
# SSN_mean                              0
# SSN_std                             497
# SSN_min                               0
# SSN_max                               0
# SSN_delta                             0
# SSN_slope                             0
# AP_last                               0
# AP_mean                               0
# AP_std                              497
# AP_min                                0
# AP_max                                0
# AP_delta                              0
# AP_slope                              0
# dtype: int64
# max---------------------- 3.446631510894068e+47

# %%
X_train = X_train.fillna(X_train.mean())

# %%
X_train = np.clip(X_train, -1e15, 1e15)

# %%
X_test = np.clip(X_test, -1e15, 1e15)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train.astype(np.float64))

X_test_scaled = scaler.transform(X_test.astype(np.float64))
# Out:
# C:\Users\Electronica Care\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\extmath.py:1207: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Electronica Care\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\extmath.py:1212: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\Electronica Care\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\extmath.py:1236: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %% [markdown]
# ## importing gradient descent

# %%
y_train
# Out:
# array([ -9.24810531, -30.        , -30.        , ...,  -9.79155864,
#        -30.        ,  -7.02830676], shape=(11942,))

# %%
import xgboost as xgb

model = xgb.XGBRegressor(
    tree_method="hist",   # تفعيل GPU
    predictor="gpu_predictor",
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

model.fit(X_train_scaled, y_train)
# Out:
# C:\Users\Electronica Care\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\training.py:200: UserWarning: [03:34:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
prediction=model.predict(X_test_scaled)
print(y_test,prediction)
# Out:
# [ -7.33226695  -7.93367407 -30.         ... -30.         -13.48439105
#  -25.12796033] [ -7.301657  -7.91696  -30.006096 ... -29.989975 -13.758352 -24.961218]

# %%
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error(y_test, prediction)
print("RMSE:", rmse)
# Out:
# RMSE: 0.22419095629564909

# %%
y_test
# Out:
# array([ -7.33226695,  -7.93367407, -30.        , ..., -30.        ,
#        -13.48439105, -25.12796033], shape=(2167,))
